# %%
# Geocoding is when an address is sent and its coordinates are recieved for the same.
# nominatim is a tool of open street maps
from geopy.geocoders import Nominatim

dir(geopy.geocoders)
# Out:
# ['ArcGIS',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeFarm',
#  'GeocoderNotFound',
#  'GoogleV3',
#  'IGNFrance',
#  'LiveAddress',
#  'Mapzen',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'What3Words',
#  'Yandex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'arcgis',
#  'baidu',
#  'base',
#  'bing',
#  'databc',
#  'geocodefarm',
#  'geonames',
#  'get_geocoder_for_service',
#  'googlev3',
#  'ignfrance',
#  'mapzen',
#  'opencage',
#  'openmapquest',
#  'options',
#  'osm',
#  'photon',
#  'pickpoint',
#  'smartystreets',
#  'what3words',
#  'yandex']

# %%
nom = Nominatim()
nom.geocode("175 5th Avenue NYC")
# Out:
# Location(Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan, Manhattan Community Board 5, New York County, NYC, New York, 10010, United States of America, (40.7410861, -73.9896298241625, 0.0))

# %%
nom.geocode("425 s 900 e salt lake city")
# Out:
# Location(425, 900 East, East Central, Greater Avenues, Salt Lake City, Salt Lake County, Utah, 84102, United States of America, (40.760059, -111.86522325, 0.0))

# %%
import pandas
df  = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df['Address'] =  df['Address'] +','+df['City'] +','+ df['Country']
df
# Out:
#    ID                            Address           City             State  \
# 0   1     3666 21st St,San Francisco,USA  San Francisco          CA 94114
# 1   2   735 Dolores St,San Francisco,USA  San Francisco          CA 94119
# 2   3      332 Hill St,San Francisco,USA  San Francisco  California 94114
# 3   4     3995 23rd St,San Francisco,USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St,San Francisco,USA  San Francisco        California
# 5   6  551 Alvarado St,San Francisco,USA  San Francisco          CA 94114
#
#   Country         Name  Employees
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20

# %%
df['Coordinates'] = df['Address'].apply(nom.geocode)
df
# Out:
#    ID                            Address           City             State  \
# 0   1     3666 21st St,San Francisco,USA  San Francisco          CA 94114
# 1   2   735 Dolores St,San Francisco,USA  San Francisco          CA 94119
# 2   3      332 Hill St,San Francisco,USA  San Francisco  California 94114
# 3   4     3995 23rd St,San Francisco,USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St,San Francisco,USA  San Francisco        California
# 5   6  551 Alvarado St,San Francisco,USA  San Francisco          CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666, 21st Street, Noe Valley, SF, California...
# 1  (735, Dolores Street, Liberty Street Historic ...
# ...

# %%
df['Coordinates'][0]
# Out:
# Location(3666, 21st Street, Noe Valley, SF, California, 94114, United States of America, (37.756488877551, -122.429343346939, 0.0))

# %%
df['Latitude'] = df['Coordinates'].apply(lambda x: x.latitude if x!= None)
df
# Out:
#    ID                            Address           City             State  \
# 0   1     3666 21st St,San Francisco,USA  San Francisco          CA 94114
# 1   2   735 Dolores St,San Francisco,USA  San Francisco          CA 94119
# 2   3      332 Hill St,San Francisco,USA  San Francisco  California 94114
# 3   4     3995 23rd St,San Francisco,USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St,San Francisco,USA  San Francisco        California
# 5   6  551 Alvarado St,San Francisco,USA  San Francisco          CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# 0  (3666, 21st Street, Noe Valley, SF, California...  37.756489
# 1  (735, Dolores Street, Liberty Street Historic ...  37.757726
# ...
